# %% [markdown]
# Offshoot from Nguyen's original file

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
# read the dataset as dataframe 
fileName = 'movies.csv'

df = pd.read_csv('../_data/_raw/' + fileName)

#Let's have a look at the dataset 
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
# IDENTIFY MISSING DATA

for col in df.columns:
    percent_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,percent_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#Since there is a small % of column with missing data, we will drop rows with null values
df = df.dropna(how='any',axis=0)

# %%
#double check and confirm there is NO null value in the data
for col in df.columns:
    percent_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,percent_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
#Data Types for our columns

print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#change format of budget and gross columns

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# add column for gross profit 
df['gross_profit'] = df['gross'] - df['budget']
df.rename(columns = {'gross' : 'gross_revenue'}) # rename gross to avoid confusion with gross_profit

# split released
df[['Release Month', 'Release Day', 'Release Year']] = df['released'].str.split(' ', n=2, expand=True)

# %%
#CLEAN DATA - drop duplicates data 

df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
#order the data from highest to lowest gross revenue


df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# To see what genre have the highest gross
groupby_gross = df.groupby(['genre'])[['gross']].mean()

fig, ax = plt.subplots()

ax.bar(groupby_gross.index, groupby_gross['gross'])

labels = ax.get_xticklabels()
plt.setp(labels, rotation = 45, horizontalalignment = 'right')

plt.title('Gross Profit by Genre')
plt.xlabel('Genre')
plt.ylabel('Gross')

plt.show()

# %%
# To see what genre have the highest budget
groupby_budget = df.groupby(['genre'])[['budget']].mean()

fig, ax = plt.subplots()

ax.bar(groupby_budget.index, groupby_budget['budget'])

labels = ax.get_xticklabels()
plt.setp(labels, rotation = 45, horizontalalignment = 'right')

plt.title('Budget by Genre')
plt.xlabel('Genre')
plt.ylabel('Budget')

plt.show()

# %%
#Regression Analysis - Correlation 
#Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earning - Correlation')
plt.xlabel('Gross Earning')
plt.ylabel('Budget for Movie')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Plot Budget vs Gross earnings using seaborn

sns.regplot(x='budget',y='gross', data =df, scatter_kws={"color":"black"}, line_kws = {"color":"yellow"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr()

#this shows a strong correlation between Gross Earning (Y- dependent variable) and Budget,Vote ( X- independent value)
# Out:
#                   year     score     votes    budget     gross   runtime  \
# year          1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score         0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes         0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget        0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross         0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime       0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# gross_profit  0.237456  0.243340  0.609203  0.610530  0.984428  0.241554
#
#               gross_profit
# year              0.237456
# score             0.243340
# votes             0.609203
# budget            0.610530
# gross             0.984428
# runtime           0.241554
# gross_profit      1.000000

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix Between Movies Features')
plt.show()

# %%
#Numberized the object datatype to analyze the correlation

df_numberized = df 

for col in df_numberized.columns:
    if df_numberized[col].dtype =='object' :
        df_numberized[col] = df_numberized[col].astype('category')
        df_numberized[col] = df_numberized[col].cat.codes # give a random numbers
        
df_numberized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  gross_profit  \
# 0   699       46  19000000   46998772     1426    146.0      27998772
# 1   214       47   4500000   58853106      452    104.0      54353106
# 2  1157       47  18000000  538375067      945    124.0     520375067
# 3  1474       47   3500000   83453539     1108     88.0      79953539
# 4   271       47   6000000   39846344     1083     98.0      33846344
#
#    Release Month  Release Day  Release Year
# 0             11            7             3
# ...

# %%
correlation_matrix = df_numberized.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix Between Movies Features')
plt.show()

# %%
correlation_mat = df_numberized.corr()

corr_pairs = correlation_mat.unstack()

sorted_pairs = corr_pairs.sort_values()

sorted_pairs.head()
# Out:
# genre   budget   -0.368523
# budget  genre    -0.368523
# genre   gross    -0.244101
# gross   genre    -0.244101
# rating  budget   -0.203946
# dtype: float64

# %%
#Filter to only pairs with high correlation ( in this case > 50%)

high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr.head()
# Out:
# gross_profit  votes           0.609203
# votes         gross_profit    0.609203
# gross_profit  budget          0.610530
# budget        gross_profit    0.610530
# votes         gross           0.614751
# dtype: float64

# %%
#In conclusion, Budget and Votes have the highest correlation with Gross Earning of the Movie
