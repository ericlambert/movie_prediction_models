# %%
# Import pertinent libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('ggplot')

# %%
# read data
dataFileName = ('../../_data/_processed/' + 'processed_for_viz.csv')

df = pd.read_csv(dataFileName)
print(df.columns)
df.head(10)
# Out:
# Index(['name', 'rating', 'genre', 'score', 'votes', 'director', 'writer',
#        'star', 'country', 'budget', 'gross revenue', 'company', 'runtime',
#        'release month', 'release day', 'release year', 'release month num',
#        'release date', 'release quarter', 'release day of week'],
#       dtype='object')
#                                              name rating      genre  score  \
# 0                                     The Shining      R      Drama    8.4
# 1                                 The Blue Lagoon      R  Adventure    5.8
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                       Airplane!     PG     Comedy    7.7
# 4                                      Caddyshack      R     Comedy    7.3
# 5                                 Friday the 13th      R     Horror    6.4
# 6                              The Blues Brothers      R     Action    7.9
# 7                                     Raging Bull      R  Biography    8.2
# 8                                     Superman II     PG     Action    6.8
# 9                                 The Long Riders      R  Biography    7.0
#
#        votes            director                   writer             star  \
# 0   927000.0     Stanley Kubrick             Stephen King   Jack Nicholson
# 1    65000.0      Randal Kleiser  Henry De Vere Stacpoole   Brooke Shields
# 2  1200000.0      Irvin Kershner           Leigh Brackett      Mark Hamill
# 3   221000.0        Jim Abrahams             Jim Abrahams      Robert Hays
# 4   108000.0        Harold Ramis       Brian Doyle-Murray      Chevy Chase
# 5   123000.0  Sean S. Cunningham            Victor Miller     Betsy Palmer
# 6   188000.0         John Landis              Dan Aykroyd     John Belushi
# 7   330000.0     Martin Scorsese             Jake LaMotta   Robert De Niro
# 8   101000.0      Richard Lester             Jerry Siegel     Gene Hackman
# 9    10000.0         Walter Hill              Bill Bryden  David Carradine
#
#           country      budget  gross revenue                       company  \
# 0  United Kingdom  19000000.0     46998772.0                  Warner Bros.
# 1   United States   4500000.0     58853106.0             Columbia Pictures
# 2   United States  18000000.0    538375067.0                     Lucasfilm
# 3   United States   3500000.0     83453539.0            Paramount Pictures
# 4   United States   6000000.0     39846344.0                Orion Pictures
# 5   United States    550000.0     39754601.0            Paramount Pictures
# 6   United States  27000000.0    115229890.0            Universal Pictures
# 7   United States  18000000.0     23402427.0  Chartoff-Winkler Productions
# 8   United States  54000000.0    108185706.0                Dovemead Films
# 9   United States  10000000.0     15795189.0                United Artists
#
#    runtime release month  release day  release year  release month num  \
# 0    146.0          June           13          1980                  6
# 1    104.0          July            2          1980                  7
# 2    124.0          June           20          1980                  6
# 3     88.0          July            2          1980                  7
# 4     98.0          July           25          1980                  7
# 5     95.0           May            9          1980                  5
# 6    133.0          June           20          1980                  6
# 7    129.0      December           19          1980                 12
# 8    127.0          June           19          1981                  6
# 9    100.0           May           16          1980                  5
#
#   release date  release quarter release day of week
# 0   1980-06-13                2              Friday
# 1   1980-07-02                3           Wednesday
# 2   1980-06-20                2              Friday
# 3   1980-07-02                3           Wednesday
# 4   1980-07-25                3              Friday
# 5   1980-05-09                2              Friday
# 6   1980-06-20                2              Friday
# 7   1980-12-19                4              Friday
# 8   1981-06-19                2              Friday
# 9   1980-05-16                2              Friday

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7357 entries, 0 to 7356
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 7357 non-null   object
#  1   rating               7357 non-null   object
#  2   genre                7357 non-null   object
#  3   score                7357 non-null   float64
#  4   votes                7357 non-null   float64
#  5   director             7357 non-null   object
#  6   writer               7357 non-null   object
#  7   star                 7357 non-null   object
#  8   country              7357 non-null   object
#  9   budget               7357 non-null   float64
#  10  gross revenue        7357 non-null   float64
#  11  company              7357 non-null   object
#  12  runtime              7357 non-null   float64
#  13  release month        7357 non-null   object
#  14  release day          7357 non-null   int64
#  15  release year         7357 non-null   int64
#  16  release month num    7357 non-null   int64
#  17  release date         7357 non-null   object
#  18  release quarter      7357 non-null   int64
#  19  release day of week  7357 non-null   object
# dtypes: float64(5), int64(4), object(11)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#              score         votes        budget  gross revenue      runtime  \
# count  7357.000000  7.357000e+03  7.357000e+03   7.357000e+03  7357.000000
# mean      6.395623  9.135618e+04  3.086005e+07   7.952152e+07   107.455485
# std       0.962316  1.658002e+05  3.750481e+07   1.666726e+08    18.549042
# min       1.900000  1.050000e+02 -3.745563e+07   3.090000e+02    63.000000
# 25%       5.800000  1.000000e+04  9.112710e+06   4.814619e+06    95.000000
# 50%       6.500000  3.500000e+04  2.000000e+07   2.090186e+07   104.000000
# 75%       7.100000  9.700000e+04  3.591635e+07   7.714239e+07   116.000000
# max       9.300000  2.400000e+06  3.560000e+08   2.847246e+09   366.000000
#
#        release day  release year  release month num  release quarter
# count  7357.000000   7357.000000        7357.000000      7357.000000
# mean     16.061166   2000.905124           6.591817         2.534185
# std       8.547953     11.036076           3.435359         1.123955
# min       1.000000   1980.000000           1.000000         1.000000
# 25%       9.000000   1992.000000           4.000000         2.000000
# 50%      16.000000   2001.000000           7.000000         3.000000
# 75%      23.000000   2010.000000          10.000000         4.000000
# max      31.000000   2020.000000          12.000000         4.000000

# %%
# Check to see if there are highly correlated features to remove
plt.figure(figsize=(14,12))
sns.heatmap(df.corr(), cmap='mako', annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(14,12))
sns.clustermap(df.corr(), cmap='mako', annot=True)

# %%
sns.pairplot(df, hue= 'score')
# Out:
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
