# %% [markdown]
# Offshoot from Moy's original file

# %%
# Import pertinent libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('ggplot')

# %%
# read data
dataFileName = ('../../_data/_processed/' + 'processed_for_viz.csv')

df = pd.read_csv(dataFileName)
print(df.columns)
df.head(10)
# Out:
# Index(['name', 'rating', 'genre', 'score', 'votes', 'director', 'writer',
#        'star', 'country', 'budget', 'gross revenue', 'company', 'runtime',
#        'gross profit', 'release month', 'release day', 'release year',
#        'release month num', 'release date', 'release quarter',
#        'release day of week'],
#       dtype='object')
#                                              name rating      genre  score  \
# 0                                     The Shining      R      Drama    8.4
# 1                                 The Blue Lagoon      R  Adventure    5.8
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                       Airplane!     PG     Comedy    7.7
# 4                                      Caddyshack      R     Comedy    7.3
# 5                                 Friday the 13th      R     Horror    6.4
# 6                              The Blues Brothers      R     Action    7.9
# 7                                     Raging Bull      R  Biography    8.2
# 8                                     Superman II     PG     Action    6.8
# 9                                 The Long Riders      R  Biography    7.0
#
#        votes            director                   writer             star  \
# 0   927000.0     Stanley Kubrick             Stephen King   Jack Nicholson
# 1    65000.0      Randal Kleiser  Henry De Vere Stacpoole   Brooke Shields
# 2  1200000.0      Irvin Kershner           Leigh Brackett      Mark Hamill
# 3   221000.0        Jim Abrahams             Jim Abrahams      Robert Hays
# 4   108000.0        Harold Ramis       Brian Doyle-Murray      Chevy Chase
# 5   123000.0  Sean S. Cunningham            Victor Miller     Betsy Palmer
# 6   188000.0         John Landis              Dan Aykroyd     John Belushi
# 7   330000.0     Martin Scorsese             Jake LaMotta   Robert De Niro
# 8   101000.0      Richard Lester             Jerry Siegel     Gene Hackman
# 9    10000.0         Walter Hill              Bill Bryden  David Carradine
#
#           country    budget  ...                       company runtime  \
# 0  United Kingdom  19000000  ...                  Warner Bros.   146.0
# 1   United States   4500000  ...             Columbia Pictures   104.0
# 2   United States  18000000  ...                     Lucasfilm   124.0
# 3   United States   3500000  ...            Paramount Pictures    88.0
# 4   United States   6000000  ...                Orion Pictures    98.0
# 5   United States    550000  ...            Paramount Pictures    95.0
# 6   United States  27000000  ...            Universal Pictures   133.0
# 7   United States  18000000  ...  Chartoff-Winkler Productions   129.0
# 8   United States  54000000  ...                Dovemead Films   127.0
# 9   United States  10000000  ...                United Artists   100.0
#
#    gross profit  release month release day  release year  release month num  \
# 0      27998772           June          13          1980                  6
# 1      54353106           July           2          1980                  7
# 2     520375067           June          20          1980                  6
# 3      79953539           July           2          1980                  7
# 4      33846344           July          25          1980                  7
# 5      39204601            May           9          1980                  5
# 6      88229890           June          20          1980                  6
# 7       5402427       December          19          1980                 12
# 8      54185706           June          19          1981                  6
# 9       5795189            May          16          1980                  5
#
#    release date release quarter  release day of week
# 0    1980-06-13               2               Friday
# 1    1980-07-02               3            Wednesday
# 2    1980-06-20               2               Friday
# 3    1980-07-02               3            Wednesday
# 4    1980-07-25               3               Friday
# 5    1980-05-09               2               Friday
# 6    1980-06-20               2               Friday
# 7    1980-12-19               4               Friday
# 8    1981-06-19               2               Friday
# 9    1980-05-16               2               Friday
#
# [10 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5407 entries, 0 to 5406
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 5407 non-null   object
#  1   rating               5407 non-null   object
#  2   genre                5407 non-null   object
#  3   score                5407 non-null   float64
#  4   votes                5407 non-null   float64
#  5   director             5407 non-null   object
#  6   writer               5407 non-null   object
#  7   star                 5407 non-null   object
#  8   country              5407 non-null   object
#  9   budget               5407 non-null   int64
#  10  gross revenue        5407 non-null   int64
#  11  company              5407 non-null   object
#  12  runtime              5407 non-null   float64
#  13  gross profit         5407 non-null   int64
#  14  release month        5407 non-null   object
#  15  release day          5407 non-null   int64
#  16  release year         5407 non-null   int64
#  17  release month num    5407 non-null   int64
#  18  release date         5407 non-null   object
#  19  release quarter      5407 non-null   int64
#  20  release day of week  5407 non-null   object
# dtypes: float64(3), int64(7), object(11)
# memory usage: 887.2+ KB

# %%
df.describe()
# Out:
#              score         votes        budget  gross revenue      runtime  \
# count  5407.000000  5.407000e+03  5.407000e+03   5.407000e+03  5407.000000
# mean      6.393194  1.153467e+05  3.608856e+07   1.034955e+08   108.169595
# std       0.962755  1.845629e+05  4.159678e+07   1.874721e+08    18.122898
# min       1.900000  1.950000e+02  6.000000e+03   3.090000e+02    63.000000
# 25%       5.800000  1.900000e+04  1.000000e+07   1.085234e+07    95.000000
# 50%       6.500000  5.200000e+04  2.200000e+07   3.729544e+07   105.000000
# 75%       7.100000  1.300000e+05  4.500000e+07   1.130424e+08   118.000000
# max       9.300000  2.400000e+06  3.560000e+08   2.847246e+09   271.000000
#
#        gross profit  release day  release year  release month num  \
# count  5.407000e+03  5407.000000   5407.000000        5407.000000
# mean   6.740694e+07    16.102645   2001.839467           6.661920
# std    1.591674e+08     8.489314     10.540925           3.463247
# min   -1.580311e+08     1.000000   1980.000000           1.000000
# 25%   -3.169639e+06     9.000000   1994.000000           4.000000
# 50%    1.400714e+07    16.000000   2002.000000           7.000000
# 75%    7.056903e+07    23.000000   2011.000000          10.000000
# max    2.610246e+09    31.000000   2020.000000          12.000000
#
#        release quarter
# count      5407.000000
# mean          2.558350
# std           1.128396
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           4.000000

# %%
# Check to see if there are highly correlated features to remove
plt.figure(figsize=(14,12))
sns.heatmap(df.corr(), cmap='mako', annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(14,12))
sns.clustermap(df.corr(), cmap='mako', annot=True)

# %%
sns.pairplot(df, hue= 'score')
# Out:
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
