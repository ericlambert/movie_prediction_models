# %%
# Import pertinent libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('ggplot')

# %%
# read data
dataFileName = ('../../_data/_processed/' + 'processed_for_viz.csv')

df = pd.read_csv(dataFileName)
print(df.columns)
df.head(10)
# Out:
# Index(['name', 'rating', 'genre', 'score', 'votes', 'director', 'writer',
#        'star', 'country', 'gross revenue', 'company', 'runtime',
#        'release month', 'release day', 'release year', 'release month num',
#        'release date', 'release quarter', 'release day of week'],
#       dtype='object')
#                                              name rating      genre  score  \
# 0                                     The Shining      R      Drama    8.4
# 1                                 The Blue Lagoon      R  Adventure    5.8
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                       Airplane!     PG     Comedy    7.7
# 4                                      Caddyshack      R     Comedy    7.3
# 5                                 Friday the 13th      R     Horror    6.4
# 6                              The Blues Brothers      R     Action    7.9
# 7                                     Raging Bull      R  Biography    8.2
# 8                                     Superman II     PG     Action    6.8
# 9                                 The Long Riders      R  Biography    7.0
#
#        votes            director                   writer             star  \
# 0   927000.0     Stanley Kubrick             Stephen King   Jack Nicholson
# 1    65000.0      Randal Kleiser  Henry De Vere Stacpoole   Brooke Shields
# 2  1200000.0      Irvin Kershner           Leigh Brackett      Mark Hamill
# 3   221000.0        Jim Abrahams             Jim Abrahams      Robert Hays
# 4   108000.0        Harold Ramis       Brian Doyle-Murray      Chevy Chase
# 5   123000.0  Sean S. Cunningham            Victor Miller     Betsy Palmer
# 6   188000.0         John Landis              Dan Aykroyd     John Belushi
# 7   330000.0     Martin Scorsese             Jake LaMotta   Robert De Niro
# 8   101000.0      Richard Lester             Jerry Siegel     Gene Hackman
# 9    10000.0         Walter Hill              Bill Bryden  David Carradine
#
#           country  gross revenue                       company  runtime  \
# 0  United Kingdom       46998772                  Warner Bros.    146.0
# 1   United States       58853106             Columbia Pictures    104.0
# 2   United States      538375067                     Lucasfilm    124.0
# 3   United States       83453539            Paramount Pictures     88.0
# 4   United States       39846344                Orion Pictures     98.0
# 5   United States       39754601            Paramount Pictures     95.0
# 6   United States      115229890            Universal Pictures    133.0
# 7   United States       23402427  Chartoff-Winkler Productions    129.0
# 8   United States      108185706                Dovemead Films    127.0
# 9   United States       15795189                United Artists    100.0
#
#   release month  release day  release year  release month num release date  \
# 0          June           13          1980                  6   1980-06-13
# 1          July            2          1980                  7   1980-07-02
# 2          June           20          1980                  6   1980-06-20
# 3          July            2          1980                  7   1980-07-02
# 4          July           25          1980                  7   1980-07-25
# 5           May            9          1980                  5   1980-05-09
# 6          June           20          1980                  6   1980-06-20
# 7      December           19          1980                 12   1980-12-19
# 8          June           19          1981                  6   1981-06-19
# 9           May           16          1980                  5   1980-05-16
#
#    release quarter release day of week
# 0                2              Friday
# 1                3           Wednesday
# 2                2              Friday
# 3                3           Wednesday
# 4                3              Friday
# 5                2              Friday
# 6                2              Friday
# 7                4              Friday
# 8                2              Friday
# 9                2              Friday

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7365 entries, 0 to 7364
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 7365 non-null   object
#  1   rating               7365 non-null   object
#  2   genre                7365 non-null   object
#  3   score                7365 non-null   float64
#  4   votes                7365 non-null   float64
#  5   director             7365 non-null   object
#  6   writer               7365 non-null   object
#  7   star                 7365 non-null   object
#  8   country              7365 non-null   object
#  9   gross revenue        7365 non-null   int64
#  10  company              7365 non-null   object
#  11  runtime              7365 non-null   float64
#  12  release month        7365 non-null   object
#  13  release day          7365 non-null   int64
#  14  release year         7365 non-null   int64
#  15  release month num    7365 non-null   int64
#  16  release date         7365 non-null   object
#  17  release quarter      7365 non-null   int64
#  18  release day of week  7365 non-null   object
# dtypes: float64(3), int64(5), object(11)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#              score         votes  gross revenue      runtime  release day  \
# count  7365.000000  7.365000e+03   7.365000e+03  7365.000000  7365.000000
# mean      6.395967  9.129603e+04   7.949033e+07   107.463272    16.062729
# std       0.963117  1.657359e+05   1.666292e+08    18.549380     8.550224
# min       1.900000  1.050000e+02   3.090000e+02    63.000000     1.000000
# 25%       5.800000  1.000000e+04   4.790801e+06    95.000000     9.000000
# 50%       6.500000  3.500000e+04   2.085152e+07   104.000000    16.000000
# 75%       7.100000  9.700000e+04   7.706825e+07   116.000000    23.000000
# max       9.300000  2.400000e+06   2.847246e+09   366.000000    31.000000
#
#        release year  release month num  release quarter
# count   7365.000000        7365.000000      7365.000000
# mean    2000.909165           6.591174         2.534012
# std       11.043358           3.434852         1.123712
# min     1980.000000           1.000000         1.000000
# 25%     1992.000000           4.000000         2.000000
# 50%     2001.000000           7.000000         3.000000
# 75%     2010.000000          10.000000         4.000000
# max     2020.000000          12.000000         4.000000

# %%
# Check to see if there are highly correlated features to remove
plt.figure(figsize=(14,12))
sns.heatmap(df.corr(), cmap='mako', annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(14,12))
sns.clustermap(df.corr(), cmap='mako', annot=True)

# %%
sns.pairplot(df, hue= 'score')
# Out:
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
