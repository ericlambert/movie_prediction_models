# %%
# Import pertinent libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('ggplot')

# %%
# read data
dataFileName = ('../../_data/_processed/' + 'processed_for_viz.csv')

df = pd.read_csv(dataFileName)
print(df.columns)
df.head(10)
# Out:
# Index(['name', 'rating', 'genre', 'score', 'votes', 'director', 'writer',
#        'star', 'country', 'budget', 'gross revenue', 'company', 'runtime',
#        'release month', 'release day', 'release year', 'release month num',
#        'release date', 'release quarter', 'release day of week', 'title',
#        'gross profit', 'profit margin', 'profit multiple'],
#       dtype='object')
#                                              name rating      genre  score  \
# 0                                     The Shining      R      Drama    8.4
# 1                                 The Blue Lagoon      R  Adventure    5.8
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                       Airplane!     PG     Comedy    7.7
# 4                                      Caddyshack      R     Comedy    7.3
# 5                                 Friday the 13th      R     Horror    6.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7169 entries, 0 to 7168
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 7169 non-null   object
#  1   rating               7169 non-null   object
#  2   genre                7169 non-null   object
#  3   score                7169 non-null   float64
#  4   votes                7169 non-null   float64
#  5   director             7169 non-null   object
#  6   writer               7169 non-null   object
#  7   star                 7169 non-null   object
#  8   country              7169 non-null   object
#  9   budget               7169 non-null   float64
#  10  gross revenue        7169 non-null   float64
#  11  company              7169 non-null   object
#  12  runtime              7169 non-null   float64
#  13  release month        7169 non-null   object
#  14  release day          7169 non-null   int64
# ...

# %%
df.describe()
# Out:
#              score         votes        budget  gross revenue      runtime  \
# count  7169.000000  7.169000e+03  7.169000e+03   7.169000e+03  7169.000000
# mean      6.376510  9.289715e+04  3.180830e+07   8.151105e+07   107.783233
# std       0.962503  1.674199e+05  3.751776e+07   1.683817e+08    18.621221
# min       1.900000  1.050000e+02  6.000000e+03   3.090000e+02    63.000000
# 25%       5.800000  1.100000e+04  1.000000e+07   5.410972e+06    95.000000
# 50%       6.400000  3.600000e+04  2.000000e+07   2.209985e+07   104.000000
# 75%       7.000000  9.900000e+04  3.700000e+07   7.981794e+07   117.000000
# max       9.300000  2.400000e+06  3.560000e+08   2.847246e+09   366.000000
#
#        release day  release year  release month num  release quarter  \
# count  7169.000000   7169.000000        7169.000000       7169.00000
# mean     16.067094   2000.886037           6.587251          2.53271
# std       8.543324     11.050197           3.440617          1.12516
# ...

# %%
# Check to see if there are highly correlated features to remove
plt.figure(figsize=(14,12))
sns.heatmap(df.corr(), cmap='mako', annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(14,12))
sns.clustermap(df.corr(), cmap='mako', annot=True)

# %%
sns.pairplot(df, hue= 'score')
# Out:
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Eric\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...

# %%
df.loc[df['budget'] <= 0].to_csv('../../_data/_processed/' + 'budget_is_negative.csv')
